# %%
import pandas as pd
import numpy as np
import requests as req
from bs4 import BeautifulSoup as bs

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time

# %%
childrendata = pd.read_csv('data/gwangju_children_2021.csv', encoding='cp949')
youthdata = pd.read_csv('data/gwangju_youth_2021.csv', encoding='cp949')
twentydata = pd.read_csv('data/gwangju_2030_2021.csv', encoding='cp949')
morefourtydata = pd.read_csv('data/gwangju_more40_2021.csv', encoding='cp949')

# %%
childrendata = childrendata.loc[:40,:]

# %%
youthdata = youthdata.loc[:40,:]
twentydata = twentydata.loc[:40,:]
morefourtydata = morefourtydata.loc[:40,:]

# %%
childrendata['ISBN']=childrendata['ISBN'].astype(str)
youthdata['ISBN']=youthdata['ISBN'].astype(str)
twentydata['ISBN']=twentydata['ISBN'].astype(str)
morefourtydata['ISBN']=morefourtydata['ISBN'].astype(str)

# %%
cISBNlist = []
yISBNlist = []
tISBNlist = []
fISBNlist = []

# %%
for i in range(40):
    cISBNlist.append(childrendata['ISBN'][i])
    yISBNlist.append(youthdata['ISBN'][i])
    tISBNlist.append(twentydata['ISBN'][i])
    fISBNlist.append(morefourtydata['ISBN'][i])

# %%
url = 'http://www.yes24.com/'

header = {
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36'
}

res = req.get(url, headers=header)
soup = bs(res.text, 'lxml')

# %%
cISBNlist
yISBNlist
tISBNlist
fISBNlist
# Out:
# ['9791165341909',
#  '9791188331796',
#  '9788965746829',
#  '9791187481720',
#  '9788970129815',
#  '9788936434267',
#  '9788972756194',
#  '9791190991070',
#  '9788970129822',
#  '9791165075064',
#  '9788901243665',
#  '9788901246086',
#  '9788965746836',
#  '9788965746843',
#  '9791158511906',
#  '9788954654753',
#  '9791196831080',
#  '9791130604626',
#  '9791191071030',
#  '9788984374164',
#  '9791190382175',
#  '9788936434120',
#  '9791190090018',
#  '9788934992493',
#  '9791189982140',
#  '9788934972464',
#  '9788998274931',
#  '9791187119845',
#  '9791190242516',
#  '9791190931151',
#  '9788936477936',
#  '9788937473098',
#  '9788998274412',
#  '9791190908634',
#  '9788901243658',
#  '9788925591711',
#  '9791191119305',
#  '9791196316808',
#  '9788965746669',
#  '9791190090261']

# %%
bookdic_jan = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_feb = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_mar = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_apr = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_may = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}

# %%
dic_data_jan = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_feb = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_mar = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_apr = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_may = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}

# %%
gwangju_jan_youth = pd.read_csv('data/gwangju_jan_youth.csv', encoding='cp949')

# %%
gwangju_jan_youth['month'] = 'jan'

# %%
gwangju_jan_youth['ISBN']=gwangju_jan_youth['ISBN'].astype(str)

# %%
gwangju_feb_youth = pd.read_csv('data/gwangju_feb_youth.csv', encoding='cp949')
gwangju_mar_youth = pd.read_csv('data/gwangju_mar_youth.csv', encoding='cp949')
gwangju_apr_youth = pd.read_csv('data/gwangju_apr_youth.csv', encoding='cp949')
gwangju_may_youth = pd.read_csv('data/gwangju_may_youth.csv', encoding='cp949')

# %%
gwangju_feb_youth['ISBN']=gwangju_feb_youth['ISBN'].astype(str)
gwangju_mar_youth['ISBN']=gwangju_mar_youth['ISBN'].astype(str)
gwangju_apr_youth['ISBN']=gwangju_apr_youth['ISBN'].astype(str)
gwangju_may_youth['ISBN']=gwangju_may_youth['ISBN'].astype(str)

# %%
gwangju_feb_youth['month'] = 'feb'
gwangju_mar_youth['month'] = 'mar'
gwangju_apr_youth['month'] = 'apr'
gwangju_may_youth['month'] = 'may'

# %%
def findBestloan_jan(df):
    for i in range(len(df)):
        dic_data_jan['ISBN'].append(df['ISBN'][i])
        dic_data_jan['loanCnt'].append(df['대출건수'][i])
        dic_data_jan['rank'].append(df['순위'][i])
        dic_data_jan['month'].append(df['month'][i])
    for j in range(len(dic_data_jan['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_jan['ISBN'][j] == yISBNlist[k]:
                bookdic_jan['ISBN'].append(dic_data_jan['ISBN'][j])
                bookdic_jan['loanCnt'].append(dic_data_jan['loanCnt'][j])
                bookdic_jan['rank'].append(dic_data_jan['rank'][j])
                bookdic_jan['month'].append(dic_data_jan['month'][j])

# %%
def findBestloan_feb(df):
    for i in range(len(df)):
        dic_data_feb['ISBN'].append(df['ISBN'][i])
        dic_data_feb['loanCnt'].append(df['대출건수'][i])
        dic_data_feb['rank'].append(df['순위'][i])
        dic_data_feb['month'].append(df['month'][i])
    for j in range(len(dic_data_feb['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_feb['ISBN'][j] == yISBNlist[k]:
                bookdic_feb['ISBN'].append(dic_data_feb['ISBN'][j])
                bookdic_feb['loanCnt'].append(dic_data_feb['loanCnt'][j])
                bookdic_feb['rank'].append(dic_data_feb['rank'][j])
                bookdic_feb['month'].append(dic_data_feb['month'][j])

# %%
def findBestloan_mar(df):
    for i in range(len(df)):
        dic_data_mar['ISBN'].append(df['ISBN'][i])
        dic_data_mar['loanCnt'].append(df['대출건수'][i])
        dic_data_mar['rank'].append(df['순위'][i])
        dic_data_mar['month'].append(df['month'][i])
    for j in range(len(dic_data_mar['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_mar['ISBN'][j] == yISBNlist[k]:
                bookdic_mar['ISBN'].append(dic_data_mar['ISBN'][j])
                bookdic_mar['loanCnt'].append(dic_data_mar['loanCnt'][j])
                bookdic_mar['rank'].append(dic_data_mar['rank'][j])
                bookdic_mar['month'].append(dic_data_mar['month'][j])

# %%
def findBestloan_apr(df):
    for i in range(len(df)):
        dic_data_apr['ISBN'].append(df['ISBN'][i])
        dic_data_apr['loanCnt'].append(df['대출건수'][i])
        dic_data_apr['rank'].append(df['순위'][i])
        dic_data_apr['month'].append(df['month'][i])
    for j in range(len(dic_data_apr['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_apr['ISBN'][j] == yISBNlist[k]:
                bookdic_apr['ISBN'].append(dic_data_apr['ISBN'][j])
                bookdic_apr['loanCnt'].append(dic_data_apr['loanCnt'][j])
                bookdic_apr['rank'].append(dic_data_apr['rank'][j])
                bookdic_apr['month'].append(dic_data_apr['month'][j])

# %%
def findBestloan_may(df):
    for i in range(len(df)):
        dic_data_may['ISBN'].append(df['ISBN'][i])
        dic_data_may['loanCnt'].append(df['대출건수'][i])
        dic_data_may['rank'].append(df['순위'][i])
        dic_data_may['month'].append(df['month'][i])
    for j in range(len(dic_data_may['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_may['ISBN'][j] == yISBNlist[k]:
                bookdic_may['ISBN'].append(dic_data_may['ISBN'][j])
                bookdic_may['loanCnt'].append(dic_data_may['loanCnt'][j])
                bookdic_may['rank'].append(dic_data_may['rank'][j])
                bookdic_may['month'].append(dic_data_may['month'][j])

# %%
findBestloan_jan(gwangju_jan_youth)
findBestloan_feb(gwangju_feb_youth)
findBestloan_mar(gwangju_mar_youth)
findBestloan_apr(gwangju_apr_youth)
findBestloan_may(gwangju_may_youth)

# %%
driver = wb.Chrome()
driver.get(url)

# %%
for i in bookdic_jan['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_jan['bookName'].append(bookName[0].text)
    else:
        bookdic_jan['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_jan['authorName'].append(authorName[0].text)
    else:
        bookdic_jan['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_jan['publisher'].append(publisherName[0].text)
    else:
        bookdic_jan['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_jan['starCnt'].append(starCnt[0].text)
    else:
        bookdic_jan['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_feb['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_feb['bookName'].append(bookName[0].text)
    else:
        bookdic_feb['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_feb['authorName'].append(authorName[0].text)
    else:
        bookdic_feb['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_feb['publisher'].append(publisherName[0].text)
    else:
        bookdic_feb['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_feb['starCnt'].append(starCnt[0].text)
    else:
        bookdic_feb['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_mar['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_mar['bookName'].append(bookName[0].text)
    else:
        bookdic_mar['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_mar['authorName'].append(authorName[0].text)
    else:
        bookdic_mar['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_mar['publisher'].append(publisherName[0].text)
    else:
        bookdic_mar['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_mar['starCnt'].append(starCnt[0].text)
    else:
        bookdic_mar['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_apr['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_apr['bookName'].append(bookName[0].text)
    else:
        bookdic_apr['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_apr['authorName'].append(authorName[0].text)
    else:
        bookdic_apr['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_apr['publisher'].append(publisherName[0].text)
    else:
        bookdic_apr['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_apr['starCnt'].append(starCnt[0].text)
    else:
        bookdic_apr['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_may['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_may['bookName'].append(bookName[0].text)
    else:
        bookdic_may['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_may['authorName'].append(authorName[0].text)
    else:
        bookdic_may['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_may['publisher'].append(publisherName[0].text)
    else:
        bookdic_may['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_may['starCnt'].append(starCnt[0].text)
    else:
        bookdic_may['starCnt'].append('0.0')
    
    driver.back()

# %%
driver.close()

# %%
bookdic_to_df_jan = pd.DataFrame(bookdic_jan)
bookdic_to_df_feb = pd.DataFrame(bookdic_feb)
bookdic_to_df_mar = pd.DataFrame(bookdic_mar)
bookdic_to_df_apr = pd.DataFrame(bookdic_apr)
bookdic_to_df_may = pd.DataFrame(bookdic_may)

# %%
# 1월 children 인기도서 데이터
bookdic_to_df_jan
# 2월
bookdic_to_df_feb
# 3월
bookdic_to_df_mar
# 4월
bookdic_to_df_apr
# 5월
bookdic_to_df_may
# Out:
#             ISBN      bookName authorName publisher starCnt month  loanCnt
# 0  9788993463316  10대와 통하는 미디어        손석춘     철수와영희     9.0   may        4
# 1  9788936456757     편의점 가는 기분        박영란        창비     8.4   may        3
# 2  9788936456788           아몬드        손원평        창비     9.1   may        3

# %%
youth_loanData_JtoM = pd.concat([bookdic_to_df_jan, bookdic_to_df_feb,
                                bookdic_to_df_mar, bookdic_to_df_apr,
                                bookdic_to_df_may])

# %%
pd.set_option('display.max_rows', None)

# %%
youth_loanData_JtoM.reset_index(inplace=True)

# %%
youth_loanData_JtoM
# Out:
#     index           ISBN                   bookName    authorName publisher  \
# 0       0  9788936456788                        아몬드           손원평        창비
# 1       1  9788936456894                        페인트           이희영        창비
# 2       2  9788936456504                      파란 아이           공선옥        창비
# 3       3  9788936456672                  용기 없는 일주일           정은숙        창비
# 4       4  9788949120836  키싱 마이 라이프 kissing my life           이옥수       비룡소
# 5       5  9788954427173                  시간을 파는 상점           김선영     자음과모음
# 6       6  9788954430586                  오즈의 의류수거함           유영민     자음과모음
# 7       7  9788977152144                청소년을 위한 국부론           김수행     두리미디어
# 8       0  9788954427173                  시간을 파는 상점           김선영     자음과모음
# 9       1  9791160943870                  산책을 듣는 시간            정은       사계절
# 10      2  9788932035772                   원 테이블 식당           유니게    문학과지성사
# 11      3  9788936456344                      계단의 집      윌리엄 슬레이터        창비
# 12      4  9788936456719                     수상한 진흙        루이스 쌔커        창비
# 13      5  9788936456788                        아몬드           손원평        창비
# 14      6  9788936456894                        페인트           이희영        창비
# 15      7  9788955889369                   기초 화학 사전      다케다 준이치로       그린북
# 16      8  9788958289319          매콤달콤 맛있는 우리 고전 시가           한기호       사계절
# 17      9  9791188912179                     구미호 식당           박현숙     특별한서재
# 18     10  9788936456023                  구덩이 HOLES        루이스 쌔커        창비
# 19     11  9788936456436               두려움에게 인사하는 법           김이윤        창비
# 20     12  9788936456450                  피그말리온 아이들           구병모        창비
# 21      0  9788936456788                        아몬드           손원평        창비
# 22      1  9791188912179                     구미호 식당           박현숙     특별한서재
# 23      2  9788934906353               돼지가 철학에 빠진 날         스티븐 로       김영사
# 24      3  9788936456931                   내일 말할 진실           정은숙        창비
# 25      4  9788954427173                  시간을 파는 상점           김선영     자음과모음
# 26      5  9788954442336                        식스팩           이재문     자음과모음
# 27      6  9791155251096               2미터 그리고 48시간           유은실       낮은산
# 28      7  9791160943870                  산책을 듣는 시간            정은       사계절
# 29      8  9791160944709            사랑에 빠질 때 나누는 말들           탁경은       사계절
# 30      9  9791188215058           10대와 통하는 심리학 이야기           노을이     철수와영희
# 31     10  9791197126734             취미는 악플, 특기는 막말           김이환      생각학교
# 32     11  9788936456023                  구덩이 HOLES        루이스 쌔커        창비
# 33     12  9788936456894                        페인트           이희영        창비
# 34     13  9788949120744                     기억 전달자        로이스 로리       비룡소
# 35     14  9788954439329                     가면생활자            조규미     자음과모음
# 36     15  9788971995945             세상은 어떻게 뉴스가 될까           홍성일       돌베개
# 37     16  9788993460674            나는 밥 먹으러 학교에 간다           박기복     행복한나무
# 38      0  9788932028705               소년, 소녀를 만나다   황순원문학촌 소나기마을    문학과지성사
# 39      1  9788932035406                 18세를 반납합니다           김혜정    문학과지성사
# 40      2  9788954439329                     가면생활자            조규미     자음과모음
# 41      3  9791196219314           소설처럼 아름다운 수학 이야기           김정희        혜다
# 42      4  9791197126734             취미는 악플, 특기는 막말           김이환      생각학교
# 43      0  9788993463316               10대와 통하는 미디어           손석춘     철수와영희
# 44      1  9788936456757                  편의점 가는 기분           박영란        창비
# 45      2  9788936456788                        아몬드           손원평        창비
#
#    starCnt month  loanCnt
# 0      9.1   jan        8
# 1      9.3   jan        7
# 2      8.5   jan        4
# 3      8.6   jan        4
# 4      8.8   jan        3
# 5      9.0   jan        3
# 6      8.8   jan        3
# 7      9.3   jan        3
# 8      9.0   feb        4
# 9      9.6   feb        4
# 10    10.0   feb        3
# 11     7.4   feb        3
# 12     8.6   feb        3
# 13     9.1   feb        3
# 14     9.3   feb        3
# 15     9.8   feb        3
# 16     9.6   feb        3
# 17     9.2   feb        3
# 18     9.1   feb        2
# 19     9.1   feb        2
# 20     8.4   feb        2
# 21     9.1   mar        4
# 22     9.2   mar        4
# 23     7.7   mar        3
# 24     9.6   mar        3
# 25     9.0   mar        3
# 26     9.4   mar        3
# 27     9.4   mar        3
# 28     9.6   mar        3
# 29     9.0   mar        3
# 30    10.0   mar        3
# 31     9.8   mar        3
# 32     9.1   mar        2
# 33     9.3   mar        2
# 34     9.1   mar        2
# 35     9.2   mar        2
# 36     8.0   mar        2
# 37     9.8   mar        2
# 38    10.0   apr        2
# 39    10.0   apr        2
# 40     9.2   apr        2
# 41     9.4   apr        2
# 42     9.8   apr        2
# 43     9.0   may        4
# 44     8.4   may        3
# 45     9.1   may        3

# %%
del youth_loanData_JtoM['index']

# %% [markdown]
# listbook1 = ['9791164060498', '이상한 과자 가게 전천당 2', '히로시마 레이코',
#             '길벗스쿨', '9.4', 'apr', 7]
# child_loanData_JtoM = child_loanData_JtoM.append(pd.Series(listbook1,
#                                                            index=child_loanData_JtoM.columns),
#                                                  ignore_index=True)

# %%
def monthnumbering(data):
    if data['month'] == 'jan':
        return '1'
    elif data['month'] == 'feb':
        return '2'
    elif data['month'] == 'mar':
        return '3'
    elif data['month'] == 'apr':
        return '4'
    elif data['month'] == 'may':
        return '5'

# %%
youth_loanData_JtoM['month'] = youth_loanData_JtoM.apply(monthnumbering, axis=1)

# %%
youth_loanData_JtoM.sort_values(['bookName', 'month'], inplace=True)

# %%
youth_loanData_JtoM.reset_index(inplace=True)

# %%
del youth_loanData_JtoM['index']

# %%
youth_loanData_JtoM
# Out:
#              ISBN                   bookName    authorName publisher starCnt  \
# 0   9788993463316               10대와 통하는 미디어           손석춘     철수와영희     9.0
# 1   9791188215058           10대와 통하는 심리학 이야기           노을이     철수와영희    10.0
# 2   9788932035406                 18세를 반납합니다           김혜정    문학과지성사    10.0
# 3   9791155251096               2미터 그리고 48시간           유은실       낮은산     9.4
# 4   9788954439329                     가면생활자            조규미     자음과모음     9.2
# 5   9788954439329                     가면생활자            조규미     자음과모음     9.2
# 6   9788936456344                      계단의 집      윌리엄 슬레이터        창비     7.4
# 7   9788936456023                  구덩이 HOLES        루이스 쌔커        창비     9.1
# 8   9788936456023                  구덩이 HOLES        루이스 쌔커        창비     9.1
# 9   9791188912179                     구미호 식당           박현숙     특별한서재     9.2
# 10  9791188912179                     구미호 식당           박현숙     특별한서재     9.2
# 11  9788949120744                     기억 전달자        로이스 로리       비룡소     9.1
# 12  9788955889369                   기초 화학 사전      다케다 준이치로       그린북     9.8
# 13  9788993460674            나는 밥 먹으러 학교에 간다           박기복     행복한나무     9.8
# 14  9788936456931                   내일 말할 진실           정은숙        창비     9.6
# 15  9788934906353               돼지가 철학에 빠진 날         스티븐 로       김영사     7.7
# 16  9788936456436               두려움에게 인사하는 법           김이윤        창비     9.1
# 17  9788958289319          매콤달콤 맛있는 우리 고전 시가           한기호       사계절     9.6
# 18  9791160944709            사랑에 빠질 때 나누는 말들           탁경은       사계절     9.0
# 19  9791160943870                  산책을 듣는 시간            정은       사계절     9.6
# 20  9791160943870                  산책을 듣는 시간            정은       사계절     9.6
# 21  9788971995945             세상은 어떻게 뉴스가 될까           홍성일       돌베개     8.0
# 22  9788932028705               소년, 소녀를 만나다   황순원문학촌 소나기마을    문학과지성사    10.0
# 23  9791196219314           소설처럼 아름다운 수학 이야기           김정희        혜다     9.4
# 24  9788936456719                     수상한 진흙        루이스 쌔커        창비     8.6
# 25  9788954427173                  시간을 파는 상점           김선영     자음과모음     9.0
# 26  9788954427173                  시간을 파는 상점           김선영     자음과모음     9.0
# 27  9788954427173                  시간을 파는 상점           김선영     자음과모음     9.0
# 28  9788954442336                        식스팩           이재문     자음과모음     9.4
# 29  9788936456788                        아몬드           손원평        창비     9.1
# 30  9788936456788                        아몬드           손원평        창비     9.1
# 31  9788936456788                        아몬드           손원평        창비     9.1
# 32  9788936456788                        아몬드           손원평        창비     9.1
# 33  9788954430586                  오즈의 의류수거함           유영민     자음과모음     8.8
# 34  9788936456672                  용기 없는 일주일           정은숙        창비     8.6
# 35  9788932035772                   원 테이블 식당           유니게    문학과지성사    10.0
# 36  9788977152144                청소년을 위한 국부론           김수행     두리미디어     9.3
# 37  9791197126734             취미는 악플, 특기는 막말           김이환      생각학교     9.8
# 38  9791197126734             취미는 악플, 특기는 막말           김이환      생각학교     9.8
# 39  9788949120836  키싱 마이 라이프 kissing my life           이옥수       비룡소     8.8
# 40  9788936456504                      파란 아이           공선옥        창비     8.5
# 41  9788936456894                        페인트           이희영        창비     9.3
# 42  9788936456894                        페인트           이희영        창비     9.3
# 43  9788936456894                        페인트           이희영        창비     9.3
# 44  9788936456757                  편의점 가는 기분           박영란        창비     8.4
# 45  9788936456450                  피그말리온 아이들           구병모        창비     8.4
#
#    month  loanCnt
# 0      5        4
# 1      3        3
# 2      4        2
# 3      3        3
# 4      3        2
# 5      4        2
# 6      2        3
# 7      2        2
# 8      3        2
# 9      2        3
# 10     3        4
# 11     3        2
# 12     2        3
# 13     3        2
# 14     3        3
# 15     3        3
# 16     2        2
# 17     2        3
# 18     3        3
# 19     2        4
# 20     3        3
# 21     3        2
# 22     4        2
# 23     4        2
# 24     2        3
# 25     1        3
# 26     2        4
# 27     3        3
# 28     3        3
# 29     1        8
# 30     2        3
# 31     3        4
# 32     5        3
# 33     1        3
# 34     1        4
# 35     2        3
# 36     1        3
# 37     3        3
# 38     4        2
# 39     1        3
# 40     1        4
# 41     1        7
# 42     2        3
# 43     3        2
# 44     5        3
# 45     2        2
