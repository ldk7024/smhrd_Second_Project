# %%
import pandas as pd
import numpy as np
import requests as req
from bs4 import BeautifulSoup as bs

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time

# %%
childrendata = pd.read_csv('data/gwangju_children_2021.csv', encoding='cp949')
youthdata = pd.read_csv('data/gwangju_youth_2021.csv', encoding='cp949')
twentydata = pd.read_csv('data/gwangju_2030_2021.csv', encoding='cp949')
morefourtydata = pd.read_csv('data/gwangju_more40_2021.csv', encoding='cp949')

# %%
childrendata = childrendata.loc[:40,:]

# %%
youthdata = youthdata.loc[:40,:]
twentydata = twentydata.loc[:40,:]
morefourtydata = morefourtydata.loc[:40,:]

# %%
childrendata['ISBN']=childrendata['ISBN'].astype(str)
youthdata['ISBN']=youthdata['ISBN'].astype(str)
twentydata['ISBN']=twentydata['ISBN'].astype(str)
morefourtydata['ISBN']=morefourtydata['ISBN'].astype(str)

# %%
cISBNlist = []
yISBNlist = []
tISBNlist = []
fISBNlist = []

# %%
for i in range(40):
    cISBNlist.append(childrendata['ISBN'][i])
    yISBNlist.append(youthdata['ISBN'][i])
    tISBNlist.append(twentydata['ISBN'][i])
    fISBNlist.append(morefourtydata['ISBN'][i])

# %%
url = 'http://www.yes24.com/'

header = {
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36'
}

res = req.get(url, headers=header)
soup = bs(res.text, 'lxml')

# %%
cISBNlist
yISBNlist
tISBNlist
fISBNlist
# Out:
# ['9791165341909',
#  '9791188331796',
#  '9788965746829',
#  '9791187481720',
#  '9788970129815',
#  '9788936434267',
#  '9788972756194',
#  '9791190991070',
#  '9788970129822',
#  '9791165075064',
#  '9788901243665',
#  '9788901246086',
#  '9788965746836',
#  '9788965746843',
#  '9791158511906',
#  '9788954654753',
#  '9791196831080',
#  '9791130604626',
#  '9791191071030',
#  '9788984374164',
#  '9791190382175',
#  '9788936434120',
#  '9791190090018',
#  '9788934992493',
#  '9791189982140',
#  '9788934972464',
#  '9788998274931',
#  '9791187119845',
#  '9791190242516',
#  '9791190931151',
#  '9788936477936',
#  '9788937473098',
#  '9788998274412',
#  '9791190908634',
#  '9788901243658',
#  '9788925591711',
#  '9791191119305',
#  '9791196316808',
#  '9788965746669',
#  '9791190090261']

# %%
bookdic_jan = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_feb = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_mar = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_apr = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}
bookdic_may = {'ISBN':[], 'bookName':[], 'authorName':[], 'publisher':[], 
           'starCnt':[], 'month':[],'rank':[], 'loanCnt':[]}

# %%
dic_data_jan = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_feb = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_mar = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_apr = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}
dic_data_may = {'ISBN':[],'loanCnt':[],'rank':[],'month':[]}

# %%
gwangju_jan_ov40 = pd.read_csv('data/gwangju_jan_ov40.csv', encoding='cp949')

# %%
gwangju_jan_ov40['month'] = 'jan'

# %%
gwangju_jan_ov40['ISBN']=gwangju_jan_ov40['ISBN'].astype(str)

# %%
gwangju_feb_ov40 = pd.read_csv('data/gwangju_feb_ov40.csv', encoding='cp949')
gwangju_mar_ov40 = pd.read_csv('data/gwangju_mar_ov40.csv', encoding='cp949')
gwangju_apr_ov40 = pd.read_csv('data/gwangju_apr_ov40.csv', encoding='cp949')
gwangju_may_ov40 = pd.read_csv('data/gwangju_may_ov40.csv', encoding='cp949')

# %%
gwangju_feb_ov40['ISBN']=gwangju_feb_ov40['ISBN'].astype(str)
gwangju_mar_ov40['ISBN']=gwangju_mar_ov40['ISBN'].astype(str)
gwangju_apr_ov40['ISBN']=gwangju_apr_ov40['ISBN'].astype(str)
gwangju_may_ov40['ISBN']=gwangju_may_ov40['ISBN'].astype(str)

# %%
gwangju_feb_ov40['month'] = 'feb'
gwangju_mar_ov40['month'] = 'mar'
gwangju_apr_ov40['month'] = 'apr'
gwangju_may_ov40['month'] = 'may'

# %%
dic_data_jan
# Out:
# {'ISBN': [], 'loanCnt': [], 'rank': [], 'month': []}

# %%
dic_data_feb
# Out:
# {'ISBN': [], 'loanCnt': [], 'rank': [], 'month': []}

# %%
def findBestloan_jan(df):
    for i in range(len(df)):
        dic_data_jan['ISBN'].append(df['ISBN'][i])
        dic_data_jan['loanCnt'].append(df['대출건수'][i])
        dic_data_jan['month'].append(df['month'][i])
        dic_data_jan['rank'].append(df['순위'][i])
    for j in range(len(dic_data_jan['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_jan['ISBN'][j] == fISBNlist[k]:
                bookdic_jan['ISBN'].append(dic_data_jan['ISBN'][j])
                bookdic_jan['loanCnt'].append(dic_data_jan['loanCnt'][j])
                bookdic_jan['rank'].append(dic_data_jan['rank'][j])
                bookdic_jan['month'].append(dic_data_jan['month'][j])

# %%
def findBestloan_feb(df):
    for i in range(len(df)):
        dic_data_feb['ISBN'].append(df['ISBN'][i])
        dic_data_feb['loanCnt'].append(df['대출건수'][i])
        dic_data_feb['month'].append(df['month'][i])
        dic_data_feb['rank'].append(df['순위'][i])
    for j in range(len(dic_data_feb['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_feb['ISBN'][j] == fISBNlist[k]:
                bookdic_feb['ISBN'].append(dic_data_feb['ISBN'][j])
                bookdic_feb['loanCnt'].append(dic_data_feb['loanCnt'][j])
                bookdic_feb['rank'].append(dic_data_feb['rank'][j])
                bookdic_feb['month'].append(dic_data_feb['month'][j])

# %%
def findBestloan_mar(df):
    for i in range(len(df)):
        dic_data_mar['ISBN'].append(df['ISBN'][i])
        dic_data_mar['loanCnt'].append(df['대출건수'][i])
        dic_data_mar['month'].append(df['month'][i])
        dic_data_mar['rank'].append(df['순위'][i])
    for j in range(len(dic_data_mar['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_mar['ISBN'][j] == fISBNlist[k]:
                bookdic_mar['ISBN'].append(dic_data_mar['ISBN'][j])
                bookdic_mar['loanCnt'].append(dic_data_mar['loanCnt'][j])
                bookdic_mar['rank'].append(dic_data_mar['rank'][j])
                bookdic_mar['month'].append(dic_data_mar['month'][j])

# %%
def findBestloan_apr(df):
    for i in range(len(df)):
        dic_data_apr['ISBN'].append(df['ISBN'][i])
        dic_data_apr['loanCnt'].append(df['대출건수'][i])
        dic_data_apr['month'].append(df['month'][i])
        dic_data_apr['rank'].append(df['순위'][i])
    for j in range(len(dic_data_apr['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_apr['ISBN'][j] == fISBNlist[k]:
                bookdic_apr['ISBN'].append(dic_data_apr['ISBN'][j])
                bookdic_apr['loanCnt'].append(dic_data_apr['loanCnt'][j])
                bookdic_apr['rank'].append(dic_data_apr['rank'][j])
                bookdic_apr['month'].append(dic_data_apr['month'][j])

# %%
def findBestloan_may(df):
    for i in range(len(df)):
        dic_data_may['ISBN'].append(df['ISBN'][i])
        dic_data_may['loanCnt'].append(df['대출건수'][i])
        dic_data_may['rank'].append(df['순위'][i])
        dic_data_may['month'].append(df['month'][i])
    for j in range(len(dic_data_may['ISBN'])):
        for k in range(len(cISBNlist)):
            if dic_data_may['ISBN'][j] == fISBNlist[k]:
                bookdic_may['ISBN'].append(dic_data_may['ISBN'][j])
                bookdic_may['loanCnt'].append(dic_data_may['loanCnt'][j])
                bookdic_may['rank'].append(dic_data_may['rank'][j])
                bookdic_may['month'].append(dic_data_may['month'][j])

# %%
findBestloan_jan(gwangju_jan_ov40)
findBestloan_feb(gwangju_feb_ov40)
findBestloan_mar(gwangju_mar_ov40)
findBestloan_apr(gwangju_apr_ov40)
findBestloan_may(gwangju_may_ov40)

# %%
driver = wb.Chrome()
driver.get(url)

# %%
for i in bookdic_jan['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_jan['bookName'].append(bookName[0].text)
    else:
        bookdic_jan['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_jan['authorName'].append(authorName[0].text)
    else:
        bookdic_jan['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_jan['publisher'].append(publisherName[0].text)
    else:
        bookdic_jan['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_jan['starCnt'].append(starCnt[0].text)
    else:
        bookdic_jan['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_feb['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_feb['bookName'].append(bookName[0].text)
    else:
        bookdic_feb['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_feb['authorName'].append(authorName[0].text)
    else:
        bookdic_feb['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_feb['publisher'].append(publisherName[0].text)
    else:
        bookdic_feb['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_feb['starCnt'].append(starCnt[0].text)
    else:
        bookdic_feb['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_mar['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_mar['bookName'].append(bookName[0].text)
    else:
        bookdic_mar['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_mar['authorName'].append(authorName[0].text)
    else:
        bookdic_mar['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_mar['publisher'].append(publisherName[0].text)
    else:
        bookdic_mar['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_mar['starCnt'].append(starCnt[0].text)
    else:
        bookdic_mar['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_apr['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_apr['bookName'].append(bookName[0].text)
    else:
        bookdic_apr['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_apr['authorName'].append(authorName[0].text)
    else:
        bookdic_apr['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_apr['publisher'].append(publisherName[0].text)
    else:
        bookdic_apr['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_apr['starCnt'].append(starCnt[0].text)
    else:
        bookdic_apr['starCnt'].append('0.0')
    
    driver.back()

# %%
for i in bookdic_may['ISBN']:
    input_area = driver.find_element_by_id('query')
    btn = driver.find_element_by_class_name('schBtn')
    
    input_area.send_keys(i)
    btn.click()
    time.sleep(2)
    
    soup = bs(driver.page_source, 'lxml')
    bookName = soup.select('p.goods_name.goods_icon > a')
    authorName = soup.select('div.goods_info > a')
    publisherName = soup.select('div.goods_info > span.dim_txt002 + a')
    starCnt = soup.select('div.goods_rating > span.gd_rating > em.yes_b')
    
    if len(bookName) != 0 :
        bookdic_may['bookName'].append(bookName[0].text)
    else:
        bookdic_may['bookName'].append('None')
        
    if len(authorName) != 0 :
        bookdic_may['authorName'].append(authorName[0].text)
    else:
        bookdic_may['authorName'].append('None')
        
    if len(publisherName) != 0 :
        bookdic_may['publisher'].append(publisherName[0].text)
    else:
        bookdic_may['publisher'].append('None')
        
    if len(starCnt) != 0 :
        bookdic_may['starCnt'].append(starCnt[0].text)
    else:
        bookdic_may['starCnt'].append('0.0')
    
    driver.back()

# %%
driver.close()

# %%
bookdic_to_df_jan = pd.DataFrame(bookdic_jan)
bookdic_to_df_feb = pd.DataFrame(bookdic_feb)
bookdic_to_df_mar = pd.DataFrame(bookdic_mar)
bookdic_to_df_apr = pd.DataFrame(bookdic_apr)
bookdic_to_df_may = pd.DataFrame(bookdic_may)

# %%
# 1월 children 인기도서 데이터
bookdic_to_df_jan
# 2월
bookdic_to_df_feb
# 3월
bookdic_to_df_mar
# 4월
bookdic_to_df_apr
# 5월
bookdic_to_df_may
# Out:
#              ISBN                           bookName authorName     publisher  \
# 0   9788970129815                              파친코 1        이민진          문학사상
# 1   9788970129822                              파친코 2        이민진          문학사상
# 2   9791188331796                     [예스리커버] 돈의 속성         김승호       스노우폭스북스
# 3   9791165341909                         달러구트 꿈 백화점        이미예         팩토리나인
# 4   9788984374164                           인생은 소설이다      기욤 뮈소          밝은세상
# 5   9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리           갤리온
# 6   9791189982140                             진이, 지니        정유정          은행나무
# 7   9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식        위즈덤하우스
# 8   9788936434267                                아몬드        손원평            창비
# 9   9788972756194               나미야 잡화점의 기적 (봄날 에디션)   히가시노 게이고          현대문학
# 10  9788998274412                              루팡의 딸    요코제키 다이          북플라자
# 11  9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽            허블
# 12  9788965746829                           천년의 질문 1        조정래            해냄
# 13  9788965746836                           천년의 질문 2        조정래            해냄
# 14  9788901246086                         2030 축의 전환     마우로 기옌          리더스북
# 15  9788965746843                           천년의 질문 3        조정래            해냄
# 16  9791187481720                        존리의 부자되기 습관         존리         지식노마드
# 17  9788936434120                             소년이 온다         한강            창비
# 18  9791190991070                             바이러스 X        김진명          이타북스
# 19  9788925591711                블랙 쇼맨과 이름 없는 마을의 살인   히가시노 게이고  알에이치코리아(RHK)
# 20  9788934992493                         죽은 자의 집 청소         김완           김영사
# 21  9788937473098                           보건교사 안은영        정세랑           민음사
# 22  9788954654753                      체리새우 : 비밀글입니다        황영미          문학동네
# 23  9791158511906                나의 하루는 4시 30분에 시작된다        김유진          토네이도
# 24  9791190090261                            천 개의 파랑        천선란            허블
# 25  9788965746669                             당신이 옳다        정혜신            해냄
# 26  9791190382175  더 해빙 The Having (40만부 기념 리커버 에디션)        이서윤          수오서재
# 27  9788901243665                           김미경의 리부트       None          None
# 28  9788936477936                        알로하, 나의 엄마들        이금이            창비
# 29  9788998274931                          봉제인형 살인사건      다니엘 콜          북플라자
# 30  9791187119845                       나는 나로 살기로 했다        김수현          마음의숲
# 31  9791165075064                           녹나무의 파수꾼   히가시노 게이고         소미미디어
# 32  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁          다산북스
# 33  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경          비에이블
# 34  9791196316808                           공부머리 독서법        최승필           책구루
# 35  9791196831080                             부의 대이동        오건영          페이지2
# 36  9788934972464                               사피엔스     유발 하라리           김영사
# 37  9791191071030                                프리즘        손원평          은행나무
#
#    starCnt month  rank  loanCnt
# 0      9.4   may     1       24
# 1      9.4   may     1       24
# 2      9.5   may     3       23
# 3      9.2   may     4       22
# 4      9.2   may     6       20
# 5      9.0   may     8       19
# 6      9.2   may     8       19
# 7      9.6   may    11       18
# 8      9.2   may    12       17
# 9      9.2   may    12       17
# 10     8.5   may    12       17
# 11     9.4   may    12       17
# 12     9.3   may    18       16
# 13     9.2   may    18       16
# 14     9.2   may    22       15
# 15     9.2   may    22       15
# 16     8.6   may    22       15
# 17     9.3   may    29       14
# 18     8.8   may    29       14
# 19     8.7   may    33       13
# 20     9.2   may    33       13
# 21     9.1   may    33       13
# 22     9.4   may    33       13
# 23     9.0   may    33       13
# 24     9.4   may    33       13
# 25     9.3   may    44       12
# 26     9.0   may    44       12
# 27     0.0   may    51       11
# 28     9.5   may    51       11
# 29     8.5   may    51       11
# 30     9.0   may    51       11
# 31     9.0   may    74       10
# 32     9.4   may    87        9
# 33    10.0   may    87        9
# 34     9.5   may    87        9
# 35     9.6   may   112        8
# 36     9.2   may   153        7
# 37     9.1   may   153        7

# %%
ov40_loanData_JtoM = pd.concat([bookdic_to_df_jan, bookdic_to_df_feb,
                                bookdic_to_df_mar, bookdic_to_df_apr,
                                bookdic_to_df_may])

# %%
pd.set_option('display.max_rows', None)

# %%
ov40_loanData_JtoM.reset_index(inplace=True)

# %%
ov40_loanData_JtoM
# Out:
#      index           ISBN                           bookName authorName  \
# 0        0  9791187481720                        존리의 부자되기 습관         존리
# 1        1  9788901243665                           김미경의 리부트       None
# 2        2  9791190382175  더 해빙 The Having (40만부 기념 리커버 에디션)        이서윤
# 3        3  9788965746829                           천년의 질문 1        조정래
# 4        4  9791165075064                           녹나무의 파수꾼   히가시노 게이고
# 5        5  9788934972464                               사피엔스     유발 하라리
# 6        6  9791158511906                나의 하루는 4시 30분에 시작된다        김유진
# 7        7  9788954654753                      체리새우 : 비밀글입니다        황영미
# 8        8  9791165341909                         달러구트 꿈 백화점        이미예
# 9        9  9791188331796                     [예스리커버] 돈의 속성         김승호
# 10      10  9791196316808                           공부머리 독서법        최승필
# 11      11  9791196831080                             부의 대이동        오건영
# 12      12  9788972756194               나미야 잡화점의 기적 (봄날 에디션)   히가시노 게이고
# 13      13  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 14      14  9791191071030                                프리즘        손원평
# 15      15  9791191119305                          그럼에도 불구하고        공지영
# 16      16  9788934992493                         죽은 자의 집 청소         김완
# 17      17  9791187119845                       나는 나로 살기로 했다        김수현
# 18      18  9791190242516                        존리의 금융문맹 탈출         존리
# 19      19  9791190991070                             바이러스 X        김진명
# 20      20  9788936434267                                아몬드        손원평
# 21      21  9788937473098                           보건교사 안은영        정세랑
# 22      22  9788965746669                             당신이 옳다        정혜신
# 23      23  9788965746836                           천년의 질문 2        조정래
# 24      24  9788965746843                           천년의 질문 3        조정래
# 25      25  9788936434120                             소년이 온다         한강
# 26      26  9788998274412                              루팡의 딸    요코제키 다이
# 27      27  9791189982140                             진이, 지니        정유정
# 28      28  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 29      29  9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 30      30  9788998274931                          봉제인형 살인사건      다니엘 콜
# 31      31  9791190090261                            천 개의 파랑        천선란
# 32      32  9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
# 33      33  9788936477936                        알로하, 나의 엄마들        이금이
# 34       0  9791190991070                             바이러스 X        김진명
# 35       1  9791188331796                     [예스리커버] 돈의 속성         김승호
# 36       2  9788936477936                        알로하, 나의 엄마들        이금이
# 37       3  9788936434267                                아몬드        손원평
# 38       4  9788965746829                           천년의 질문 1        조정래
# 39       5  9791191071030                                프리즘        손원평
# 40       6  9788901243665                           김미경의 리부트       None
# 41       7  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 42       8  9791165341909                         달러구트 꿈 백화점        이미예
# 43       9  9791187481720                        존리의 부자되기 습관         존리
# 44      10  9791190242516                        존리의 금융문맹 탈출         존리
# 45      11  9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
# 46      12  9788937473098                           보건교사 안은영        정세랑
# 47      13  9788965746843                           천년의 질문 3        조정래
# 48      14  9788998274931                          봉제인형 살인사건      다니엘 콜
# 49      15  9791158511906                나의 하루는 4시 30분에 시작된다        김유진
# 50      16  9791165075064                           녹나무의 파수꾼   히가시노 게이고
# 51      17  9791190382175  더 해빙 The Having (40만부 기념 리커버 에디션)        이서윤
# 52      18  9791196831080                             부의 대이동        오건영
# 53      19  9788901246086                         2030 축의 전환     마우로 기옌
# 54      20  9788934972464                               사피엔스     유발 하라리
# 55      21  9788965746836                           천년의 질문 2        조정래
# 56      22  9788936434120                             소년이 온다         한강
# 57      23  9791187119845                       나는 나로 살기로 했다        김수현
# 58      24  9788934992493                         죽은 자의 집 청소         김완
# 59      25  9788970129815                              파친코 1        이민진
# 60      26  9788972756194               나미야 잡화점의 기적 (봄날 에디션)   히가시노 게이고
# 61      27  9788954654753                      체리새우 : 비밀글입니다        황영미
# 62      28  9788970129822                              파친코 2        이민진
# 63      29  9791189982140                             진이, 지니        정유정
# 64      30  9791191119305                          그럼에도 불구하고        공지영
# 65      31  9788984374164                           인생은 소설이다      기욤 뮈소
# 66      32  9791190090261                            천 개의 파랑        천선란
# 67      33  9791196316808                           공부머리 독서법        최승필
# 68      34  9788998274412                              루팡의 딸    요코제키 다이
# 69      35  9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 70      36  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 71      37  9788925591711                블랙 쇼맨과 이름 없는 마을의 살인   히가시노 게이고
# 72       0  9791165341909                         달러구트 꿈 백화점        이미예
# 73       1  9791188331796                     [예스리커버] 돈의 속성         김승호
# 74       2  9788925591711                블랙 쇼맨과 이름 없는 마을의 살인   히가시노 게이고
# 75       3  9788970129815                              파친코 1        이민진
# 76       4  9788972756194               나미야 잡화점의 기적 (봄날 에디션)   히가시노 게이고
# 77       5  9791187481720                        존리의 부자되기 습관         존리
# 78       6  9791165075064                           녹나무의 파수꾼   히가시노 게이고
# 79       7  9788901243665                           김미경의 리부트       None
# 80       8  9788901246086                         2030 축의 전환     마우로 기옌
# 81       9  9788965746829                           천년의 질문 1        조정래
# 82      10  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 83      11  9791196831080                             부의 대이동        오건영
# 84      12  9788936434267                                아몬드        손원평
# 85      13  9791190242516                        존리의 금융문맹 탈출         존리
# 86      14  9788970129822                              파친코 2        이민진
# 87      15  9788984374164                           인생은 소설이다      기욤 뮈소
# 88      16  9791158511906                나의 하루는 4시 30분에 시작된다        김유진
# 89      17  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 90      18  9788936434120                             소년이 온다         한강
# 91      19  9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 92      20  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 93      21  9791191071030                                프리즘        손원평
# 94      22  9788954654753                      체리새우 : 비밀글입니다        황영미
# 95      23  9788965746836                           천년의 질문 2        조정래
# 96      24  9788965746843                           천년의 질문 3        조정래
# 97      25  9788998274412                              루팡의 딸    요코제키 다이
# 98      26  9788998274931                          봉제인형 살인사건      다니엘 콜
# 99      27  9788934992493                         죽은 자의 집 청소         김완
# 100     28  9791190991070                             바이러스 X        김진명
# 101     29  9791190090261                            천 개의 파랑        천선란
# 102     30  9791187119845                       나는 나로 살기로 했다        김수현
# 103     31  9791190382175  더 해빙 The Having (40만부 기념 리커버 에디션)        이서윤
#
788925591711                블랙 쇼맨과 이름 없는 마을의 살인   히가시노 게이고
# 169     20  9788934992493                         죽은 자의 집 청소         김완
# 170     21  9788937473098                           보건교사 안은영        정세랑
# 171     22  9788954654753                      체리새우 : 비밀글입니다        황영미
# 172     23  9791158511906                나의 하루는 4시 30분에 시작된다        김유진
# 173     24  9791190090261                            천 개의 파랑        천선란
# 174     25  9788965746669                             당신이 옳다        정혜신
# 175     26  9791190382175  더 해빙 The Having (40만부 기념 리커버 에디션)        이서윤
# 176     27  9788901243665                           김미경의 리부트       None
# 177     28  9788936477936                        알로하, 나의 엄마들        이금이
# 178     29  9788998274931                          봉제인형 살인사건      다니엘 콜
# 179     30  9791187119845                       나는 나로 살기로 했다        김수현
# 180     31  9791165075064                           녹나무의 파수꾼   히가시노 게이고
# 181     32  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 182     33  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 183     34  9791196316808                           공부머리 독서법        최승필
# 184     35  9791196831080                             부의 대이동        오건영
# 185     36  9788934972464                               사피엔스     유발 하라리
# 186     37  9791191071030                                프리즘        손원평
#
#         publisher starCnt month  rank  loanCnt
# 0           지식노마드     8.6   jan     1       27
# 1            None     0.0   jan     2       26
# 2            수오서재     9.0   jan     3       24
# 3              해냄     9.3   jan     4       22
# 4           소미미디어     9.0   jan     4       22
# 5             김영사     9.2   jan     6       21
# 6            토네이도     9.0   jan     6       21
# 7            문학동네     9.4   jan     9       19
# 8           팩토리나인     9.2   jan     9       19
# 9         스노우폭스북스     9.5   jan     9       19
# 10            책구루     9.5   jan     9       19
# 11           페이지2     9.6   jan     9       19
# 12           현대문학     9.2   jan    14       17
# 13           비에이블    10.0   jan    14       17
# 14           은행나무     9.1   jan    14       17
# 15         위즈덤하우스     9.4   jan    14       17
# 16            김영사     9.2   jan    20       16
# 17           마음의숲     9.0   jan    25       15
# 18           베가북스     8.8   jan    25       15
# 19           이타북스     8.8   jan    25       15
# 20             창비     9.2   jan    30       14
# 21            민음사     9.1   jan    30       14
# 22             해냄     9.3   jan    30       14
# 23             해냄     9.2   jan    30       14
# 24             해냄     9.2   jan    30       14
# 25             창비     9.3   jan    42       13
# 26           북플라자     8.5   jan    42       13
# 27           은행나무     9.2   jan    42       13
# 28           다산북스     9.4   jan    53       12
# 29             허블     9.4   jan    53       12
# 30           북플라자     8.5   jan    65       11
# 31             허블     9.4   jan    65       11
# 32            갤리온     9.0   jan   140        8
# 33             창비     9.5   jan   140        8
# 34           이타북스     8.8   feb     1       26
# 35        스노우폭스북스     9.5   feb     2       23
# 36             창비     9.5   feb     3       21
# 37             창비     9.2   feb     4       19
# 38             해냄     9.3   feb     4       19
# 39           은행나무     9.1   feb     4       19
# 40           None     0.0   feb     7       18
# 41           다산북스     9.4   feb     8       17
# 42          팩토리나인     9.2   feb     8       17
# 43          지식노마드     8.6   feb     8       17
# 44           베가북스     8.8   feb     8       17
# 45            갤리온     9.0   feb    13       16
# 46            민음사     9.1   feb    13       16
# 47             해냄     9.2   feb    13       16
# 48           북플라자     8.5   feb    13       16
# 49           토네이도     9.0   feb    13       16
# 50          소미미디어     9.0   feb    13       16
# 51           수오서재     9.0   feb    13       16
# 52           페이지2     9.6   feb    13       16
# 53           리더스북     9.2   feb    21       15
# 54            김영사     9.2   feb    21       15
# 55             해냄     9.2   feb    21       15
# 56             창비     9.3   feb    24       14
# 57           마음의숲     9.0   feb    24       14
# 58            김영사     9.2   feb    30       13
# 59           문학사상     9.4   feb    30       13
# 60           현대문학     9.2   feb    30       13
# 61           문학동네     9.4   feb    34       12
# 62           문학사상     9.4   feb    34       12
# 63           은행나무     9.2   feb    47       11
# 64         위즈덤하우스     9.4   feb    47       11
# 65           밝은세상     9.2   feb    53       10
# 66             허블     9.4   feb    53       10
# 67            책구루     9.5   feb    53       10
# 68           북플라자     8.5   feb    74        9
# 69             허블     9.4   feb    74        9
# 70         위즈덤하우스     9.6   feb   103        8
# 71   알에이치코리아(RHK)     8.7   feb   143        7
# 72          팩토리나인     9.2   mar     1       31
# 73        스노우폭스북스     9.5   mar     2       26
# 74   알에이치코리아(RHK)     8.7   mar     4       20
# 75           문학사상     9.4   mar     4       20
# 76           현대문학     9.2   mar     4       20
# 77          지식노마드     8.6   mar     4       20
# 78          소미미디어     9.0   mar     8       19
# 79           None     0.0   mar     9       18
# 80           리더스북     9.2   mar     9       18
# 81             해냄     9.3   mar     9       18
# 82           다산북스     9.4   mar     9       18
# 83           페이지2     9.6   mar     9       18
# 84             창비     9.2   mar    14       17
# 85           베가북스     8.8   mar    14       17
# 86           문학사상     9.4   mar    16       16
# 87           밝은세상     9.2   mar    16       16
# 88           토네이도     9.0   mar    18       15
# 89         위즈덤하우스     9.6   mar    18       15
# 90             창비     9.3   mar    20       14
# 91             허블     9.4   mar    20       14
# 92           비에이블    10.0   mar    20       14
# 93           은행나무     9.1   mar    20       14
# 94           문학동네     9.4   mar    28       13
# 95             해냄     9.2   mar    28       13
# 96             해냄     9.2   mar    28       13
# 97           북플라자     8.5   mar    28       13
# 98           북플라자     8.5   mar    28       13
# 99            김영사     9.2   mar    37       12
# 100          이타북스     8.8   mar    37       12
# 101            허블     9.4   mar    46       11
# 102          마음의숲     9.0   mar    57       10
# 103          수오서재     9.0   mar    57       10
# 104        위즈덤하우스     9.4   mar    57       10
# 105           책구루     9.5   mar    57       10
# 106            해냄     9.3   mar    74        9
# 107          은행나무     9.2   mar    74        9
# 108           김영사     9.2   mar    97        8
# 109            창비     9.5   mar    97        8
# 110           민음사     9.1   mar    97        8
# 111          리더스북     9.2   apr     1       26
# 112          문학사상     9.4   apr     2       24
# 113          문학사상     9.4   apr     3       23
# 114          밝은세상     9.2   apr     4       22
# 115         팩토리나인     9.2   apr     5       21
# 116            해냄     9.3   apr     6       20
# 117            창비     9.2   apr     8       19
# 118  알에이치코리아(RHK)     8.7   apr     9       18
# 119            해냄     9.2   apr     9       18
# 120            해냄     9.2   apr     9       18
# 121       스노우폭스북스     9.5   apr     9       18
# 122          현대문학     9.2   apr    17       15
# 123          이타북스     8.8   apr    17       15
# 124          문학동네     9.4   apr    21       14
# 125          다산북스     9.4   apr    21       14
# 126         소미미디어     9.0   apr    21       14
# 127         지식노마드     8.6   apr    21       14
# 128          비에이블    10.0   apr    21       14
# 129        위즈덤하우스     9.4   apr    21       14
# 130            해냄     9.3   apr    31       13
# 131            허블     9.4   apr    36       12
# 132          은행나무     9.1   apr    36       12
# 133            창비     9.5   apr    45       11
# 134        위즈덤하우스     9.6   apr    45       11
# 135           갤리온     9.0   apr    59       10
# 136          마음의숲     9.0   apr    59       10
# 137            허블     9.4   apr    59       10
# 138           책구루     9.5   apr    59       10
# 139          페이지2     9.6   apr    59       10
# 140           김영사     9.2   apr    76        9
# 141          북플라자     8.5   apr    76        9
# 142          은행나무     9.2   apr    76        9
# 143           민음사     9.1   apr   101        8
# 144          토네이도     9.0   apr   101        8
# 145           김영사     9.2   apr   137        7
# 146            창비     9.3   apr   137        7
# 147          북플라자     8.5   apr   137        7
# 148          베가북스     8.8   apr   137        7
# 149          문학사상     9.4   may     1       24
# 150          문학사상     9.4   may     1       24
# 151       스노우폭스북스     9.5   may     3       23
# 152         팩토리나인     9.2   may     4       22
# 153          밝은세상     9.2   may     6       20
# 154           갤리온     9.0   may     8       19
# 155          은행나무     9.2   may     8       19
# 156        위즈덤하우스     9.6   may    11       18
# 157            창비     9.2   may    12       17
# 158          현대문학     9.2   may    12       17
# 159          북플라자     8.5   may    12       17
# 160            허블     9.4   may    12       17
# 161            해냄     9.3   may    18       16
# 162            해냄     9.2   may    18       16
# 163          리더스북     9.2   may    22       15
# 164            해냄     9.2   may    22       15
# 165         지식노마드     8.6   may    22       15
# 166            창비     9.3   may    29       14
# 167          이타북스     8.8   may    29       14
# 168  알에이치코리아(RHK)     8.7   may    33       13
# 169           김영사     9.2   may    33       13
# 170           민음사     9.1   may    33       13
# 171          문학동네     9.4   may    33       13
# 172          토네이도     9.0   may    33       13
# 173            허블     9.4   may    33       13
# 174            해냄     9.3   may    44       12
# 175          수오서재     9.0   may    44       12
# 176          None     0.0   may    51       11
# 177            창비     9.5   may    51       11
# 178          북플라자     8.5   may    51       11
# 179          마음의숲     9.0   may    51       11
# 180         소미미디어     9.0   may    74       10
# 181          다산북스     9.4   may    87        9
# 182          비에이블    10.0   may    87        9
# 183           책구루     9.5   may    87        9
# 184          페이지2     9.6   may   112        8
# 185           김영사     9.2   may   153        7
# 186          은행나무     9.1   may   153        7

# %%
del ov40_loanData_JtoM['index']

# %%
ov40_loanData_JtoM['bookName'].value_counts()
# Out:
# 소년이 온다                               5
# 나의 하루는 4시 30분에 시작된다                  5
# 좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)           5
# 파친코 2                                5
# 봉제인형 살인사건                            5
# 부의 대이동                               5
# 진이, 지니                               5
# 보건교사 안은영                             5
# 천년의 질문 1                             5
# 기분이 태도가 되지 않게 (썸머 에디션)               5
# 2030 축의 전환                           5
# 블랙 쇼맨과 이름 없는 마을의 살인                  5
# 파친코 1                                5
# 천 개의 파랑                              5
# 초등 완성 매일 영어책 읽기 습관                   5
# [예스리커버] 돈의 속성                        5
# 존리의 금융문맹 탈출                          5
# 사피엔스                                 5
# 알로하, 나의 엄마들                          5
# 그럼에도 불구하고                            5
# 체리새우 : 비밀글입니다                        5
# 공부머리 독서법                             5
# 존리의 부자되기 습관                          5
# 인생은 소설이다                             5
# 달러구트 꿈 백화점                           5
# 바이러스 X                               5
# 더 해빙 The Having (40만부 기념 리커버 에디션)    5
# 천년의 질문 3                             5
# 당신이 옳다                               5
# 나미야 잡화점의 기적 (봄날 에디션)                 5
# 루팡의 딸                                5
# 나는 나로 살기로 했다                         5
# 아몬드                                  5
# [예스리커버] 우리가 빛의 속도로 갈 수 없다면           5
# 이토록 공부가 재미있어지는 순간                    5
# 녹나무의 파수꾼                             5
# 프리즘                                  5
# 천년의 질문 2                             5
# 죽은 자의 집 청소                           5
# 김미경의 리부트                             5
# Name: bookName, dtype: int64

# %%
ov40_loanData_JtoM[ov40_loanData_JtoM['bookName']=='파친코 2']
# Out:
#               ISBN bookName authorName publisher starCnt month  rank  loanCnt
# 179  9788970129822    파친코 2        이민진      문학사상     9.4     2    34       12
# 180  9788970129822    파친코 2        이민진      문학사상     9.4     3    16       16
# 181  9788970129822    파친코 2        이민진      문학사상     9.4     4     3       23
# 182  9788970129822    파친코 2        이민진      문학사상     9.4     5     1       24

# %%
# jan에 200위 안에 없음
listbook1 = ['9788970129822', '파친코 2', '이민진',
            '문학사상', '9.4', '1', 200 , 6]
ov40_loanData_JtoM = ov40_loanData_JtoM.append(pd.Series(listbook1, 
                                                           index=ov40_loanData_JtoM.columns), 
                                                 ignore_index=True)

# %%
def monthnumbering(data):
    if data['month'] == 'jan':
        return '1'
    elif data['month'] == 'feb':
        return '2'
    elif data['month'] == 'mar':
        return '3'
    elif data['month'] == 'apr':
        return '4'
    elif data['month'] == 'may':
        return '5'

# %%
ov40_loanData_JtoM['month'] = ov40_loanData_JtoM.apply(monthnumbering, axis=1)

# %%
ov40_loanData_JtoM.sort_values(['bookName', 'month'], inplace=True)

# %%
ov40_loanData_JtoM.reset_index(inplace=True)

# %%
del ov40_loanData_JtoM['index']

# %%
ov40_loanData_JtoM
# Out:
#               ISBN                           bookName authorName  \
# 0    9788901246086                         2030 축의 전환     마우로 기옌
# 1    9788901246086                         2030 축의 전환     마우로 기옌
# 2    9788901246086                         2030 축의 전환     마우로 기옌
# 3    9788901246086                         2030 축의 전환     마우로 기옌
# 4    9788901246086                         2030 축의 전환     마우로 기옌
# 5    9791188331796                     [예스리커버] 돈의 속성         김승호
# 6    9791188331796                     [예스리커버] 돈의 속성         김승호
# 7    9791188331796                     [예스리커버] 돈의 속성         김승호
# 8    9791188331796                     [예스리커버] 돈의 속성         김승호
# 9    9791188331796                     [예스리커버] 돈의 속성         김승호
# 10   9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 11   9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 12   9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 13   9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 14   9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
# 15   9791196316808                           공부머리 독서법        최승필
# 16   9791196316808                           공부머리 독서법        최승필
# 17   9791196316808                           공부머리 독서법        최승필
# 18   9791196316808                           공부머리 독서법        최승필
# 19   9791196316808                           공부머리 독서법        최승필
# 20   9791191119305                          그럼에도 불구하고        공지영
# 21   9791191119305                          그럼에도 불구하고        공지영
# 22   9791191119305                          그럼에도 불구하고        공지영
# 23   9791191119305                          그럼에도 불구하고        공지영
# 24   9791191119305                          그럼에도 불구하고        공지영
# 25   9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
# 26   9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
# 27   9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
# 28   9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
# 29   9788901243658             기분이 태도가 되지 않게 (썸머 에디션)       레몬심리
#
9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 121  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 122  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 123  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 124  9791130604626                  이토록 공부가 재미있어지는 순간        박성혁
# 125  9788984374164                           인생은 소설이다      기욤 뮈소
# 126  9788984374164                           인생은 소설이다      기욤 뮈소
# 127  9788984374164                           인생은 소설이다      기욤 뮈소
# 128  9788984374164                           인생은 소설이다      기욤 뮈소
# 129  9788984374164                           인생은 소설이다      기욤 뮈소
# 130  9791190242516                        존리의 금융문맹 탈출         존리
# 131  9791190242516                        존리의 금융문맹 탈출         존리
# 132  9791190242516                        존리의 금융문맹 탈출         존리
# 133  9791190242516                        존리의 금융문맹 탈출         존리
# 134  9791190242516                        존리의 금융문맹 탈출         존리
# 135  9791187481720                        존리의 부자되기 습관         존리
# 136  9791187481720                        존리의 부자되기 습관         존리
# 137  9791187481720                        존리의 부자되기 습관         존리
# 138  9791187481720                        존리의 부자되기 습관         존리
# 139  9791187481720                        존리의 부자되기 습관         존리
# 140  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 141  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 142  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 143  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 144  9791190908634         좋은 사람에게만 좋은 사람이면 돼 (봄 에디션)        김재식
# 145  9788934992493                         죽은 자의 집 청소         김완
# 146  9788934992493                         죽은 자의 집 청소         김완
# 147  9788934992493                         죽은 자의 집 청소         김완
# 148  9788934992493                         죽은 자의 집 청소         김완
# 149  9788934992493                         죽은 자의 집 청소         김완
# 150  9791189982140                             진이, 지니        정유정
# 151  9791189982140                             진이, 지니        정유정
# 152  9791189982140                             진이, 지니        정유정
# 153  9791189982140                             진이, 지니        정유정
# 154  9791189982140                             진이, 지니        정유정
# 155  9791190090261                            천 개의 파랑        천선란
# 156  9791190090261                            천 개의 파랑        천선란
# 157  9791190090261                            천 개의 파랑        천선란
# 158  9791190090261                            천 개의 파랑        천선란
# 159  9791190090261                            천 개의 파랑        천선란
# 160  9788965746829                           천년의 질문 1        조정래
# 161  9788965746829                           천년의 질문 1        조정래
# 162  9788965746829                           천년의 질문 1        조정래
# 163  9788965746829                           천년의 질문 1        조정래
# 164  9788965746829                           천년의 질문 1        조정래
# 165  9788965746836                           천년의 질문 2        조정래
# 166  9788965746836                           천년의 질문 2        조정래
# 167  9788965746836                           천년의 질문 2        조정래
# 168  9788965746836                           천년의 질문 2        조정래
# 169  9788965746836                           천년의 질문 2        조정래
# 170  9788965746843                           천년의 질문 3        조정래
# 171  9788965746843                           천년의 질문 3        조정래
# 172  9788965746843                           천년의 질문 3        조정래
# 173  9788965746843                           천년의 질문 3        조정래
# 174  9788965746843                           천년의 질문 3        조정래
# 175  9788954654753                      체리새우 : 비밀글입니다        황영미
# 176  9788954654753                      체리새우 : 비밀글입니다        황영미
# 177  9788954654753                      체리새우 : 비밀글입니다        황영미
# 178  9788954654753                      체리새우 : 비밀글입니다        황영미
# 179  9788954654753                      체리새우 : 비밀글입니다        황영미
# 180  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 181  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 182  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 183  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 184  9791190931151                 초등 완성 매일 영어책 읽기 습관        이은경
# 185  9788970129815                              파친코 1        이민진
# 186  9788970129815                              파친코 1        이민진
# 187  9788970129815                              파친코 1        이민진
# 188  9788970129815                              파친코 1        이민진
# 189  9788970129815                              파친코 1        이민진
# 190  9788970129822                              파친코 2        이민진
# 191  9788970129822                              파친코 2        이민진
# 192  9788970129822                              파친코 2        이민진
# 193  9788970129822                              파친코 2        이민진
# 194  9788970129822                              파친코 2        이민진
# 195  9791191071030                                프리즘        손원평
# 196  9791191071030                                프리즘        손원평
# 197  9791191071030                                프리즘        손원평
# 198  9791191071030                                프리즘        손원평
# 199  9791191071030                                프리즘        손원평
#
#         publisher starCnt month  rank  loanCnt
# 0            리더스북     9.2     1   200        6
# 1            리더스북     9.2     2    21       15
# 2            리더스북     9.2     3     9       18
# 3            리더스북     9.2     4     1       26
# 4            리더스북     9.2     5    22       15
# 5         스노우폭스북스     9.5     1     9       19
# 6         스노우폭스북스     9.5     2     2       23
# 7         스노우폭스북스     9.5     3     2       26
# 8         스노우폭스북스     9.5     4     9       18
# 9         스노우폭스북스     9.5     5     3       23
# 10             허블     9.4     1    53       12
# 11             허블     9.4     2    74        9
# 12             허블     9.4     3    20       14
# 13             허블     9.4     4    59       10
# 14             허블     9.4     5    12       17
# 15            책구루     9.5     1     9       19
# 16            책구루     9.5     2    53       10
# 17            책구루     9.5     3    57       10
# 18            책구루     9.5     4    59       10
# 19            책구루     9.5     5    87        9
# 20         위즈덤하우스     9.4     1    14       17
# 21         위즈덤하우스     9.4     2    47       11
# 22         위즈덤하우스     9.4     3    57       10
# 23         위즈덤하우스     9.4     4    21       14
# 24         위즈덤하우스     9.4     5   200        6
# 25            갤리온     9.0     1   140        8
# 26            갤리온     9.0     2    13       16
# 27            갤리온     9.0     3   200        5
# 28            갤리온     9.0     4    59       10
# 29            갤리온     9.0     5     8       19
# 30           None     0.0     1     2       26
# 31           None     0.0     2     7       18
# 32           None     0.0     3     9       18
# 33           None     0.0     4   200        5
# 34           None     0.0     5    51       11
# 35           마음의숲     9.0     1    25       15
# 36           마음의숲     9.0     2    24       14
# 37           마음의숲     9.0     3    57       10
# 38           마음의숲     9.0     4    59       10
# 39           마음의숲     9.0     5    51       11
# 40           현대문학     9.2     1    14       17
# 41           현대문학     9.2     2    30       13
# 42           현대문학     9.2     3     4       20
# 43           현대문학     9.2     4    17       15
# 44           현대문학     9.2     5    12       17
# 45           토네이도     9.0     1     6       21
# 46           토네이도     9.0     2    13       16
# 47           토네이도     9.0     3    18       15
# 48           토네이도     9.0     4   101        8
# 49           토네이도     9.0     5    33       13
# 50          소미미디어     9.0     1     4       22
# 51          소미미디어     9.0     2    13       16
# 52          소미미디어     9.0     3     8       19
# 53          소미미디어     9.0     4    21       14
# 54          소미미디어     9.0     5    74       10
# 55          팩토리나인     9.2     1     9       19
# 56          팩토리나인     9.2     2     8       17
# 57          팩토리나인     9.2     3     1       31
# 58          팩토리나인     9.2     4     5       21
# 59          팩토리나인     9.2     5     4       22
# 60             해냄     9.3     1    30       14
# 61             해냄     9.3     2   200        5
# 62             해냄     9.3     3    74        9
# 63             해냄     9.3     4    31       13
# 64             해냄     9.3     5    44       12
# 65           수오서재     9.0     1     3       24
# 66           수오서재     9.0     2    13       16
# 67           수오서재     9.0     3    57       10
# 68           수오서재     9.0     4   200        5
# 69           수오서재     9.0     5    44       12
# 70           북플라자     8.5     1    42       13
# 71           북플라자     8.5     2    74        9
# 72           북플라자     8.5     3    28       13
# 73           북플라자     8.5     4   137        7
# 74           북플라자     8.5     5    12       17
# 75           이타북스     8.8     1    25       15
# 76           이타북스     8.8     2     1       26
# 77           이타북스     8.8     3    37       12
# 78           이타북스     8.8     4    17       15
# 79           이타북스     8.8     5    29       14
# 80            민음사     9.1     1    30       14
# 81            민음사     9.1     2    13       16
# 82            민음사     9.1     3    97        8
# 83            민음사     9.1     4   101        8
# 84            민음사     9.1     5    33       13
# 85           북플라자     8.5     1    65       11
# 86           북플라자     8.5     2    13       16
# 87           북플라자     8.5     3    28       13
# 88           북플라자     8.5     4    76        9
# 89           북플라자     8.5     5    51       11
# 90           페이지2     9.6     1     9       19
# 91           페이지2     9.6     2    13       16
# 92           페이지2     9.6     3     9       18
# 93           페이지2     9.6     4    59       10
# 94           페이지2     9.6     5   112        8
# 95   알에이치코리아(RHK)     8.7     1   200        6
# 96   알에이치코리아(RHK)     8.7     2   143        7
# 97   알에이치코리아(RHK)     8.7     3     4       20
# 98   알에이치코리아(RHK)     8.7     4     9       18
# 99   알에이치코리아(RHK)     8.7     5    33       13
# 100           김영사     9.2     1     6       21
# 101           김영사     9.2     2    21       15
# 102           김영사     9.2     3    97        8
# 103           김영사     9.2     4    76        9
# 104           김영사     9.2     5   153        7
# 105            창비     9.3     1    42       13
# 106            창비     9.3     2    24       14
# 107            창비     9.3     3    20       14
# 108            창비     9.3     4   137        7
# 109            창비     9.3     5    29       14
# 110            창비     9.2     1    30       14
# 111            창비     9.2     2     4       19
# 112            창비     9.2     3    14       17
# 113            창비     9.2     4     8       19
# 114            창비     9.2     5    12       17
# 115            창비     9.5     1   140        8
# 116            창비     9.5     2     3       21
# 117            창비     9.5     3    97        8
# 118            창비     9.5     4    45       11
# 119            창비     9.5     5    51       11
# 120          다산북스     9.4     1    53       12
# 121          다산북스     9.4     2     8       17
# 122          다산북스     9.4     3     9       18
# 123          다산북스     9.4     4    21       14
# 124          다산북스     9.4     5    87        9
# 125          밝은세상     9.2     1   200        6
# 126          밝은세상     9.2     2    53       10
# 127          밝은세상     9.2     3    16       16
# 128          밝은세상     9.2     4     4       22
# 129          밝은세상     9.2     5     6       20
# 130          베가북스     8.8     1    25       15
# 131          베가북스     8.8     2     8       17
# 132          베가북스     8.8     3    14       17
# 133          베가북스     8.8     4   137        7
# 134          베가북스     9.2     5   200        6
# 135         지식노마드     8.6     1     1       27
# 136         지식노마드     8.6     2     8       17
# 137         지식노마드     8.6     3     4       20
# 138         지식노마드     8.6     4    21       14
# 139         지식노마드     8.6     5    22       15
# 140        위즈덤하우스     9.6     1   200        6
# 141        위즈덤하우스     9.6     2   103        8
# 142        위즈덤하우스     9.6     3    18       15
# 143        위즈덤하우스     9.6     4    45       11
# 144        위즈덤하우스     9.6     5    11       18
# 145           김영사     9.2     1    20       16
# 146           김영사     9.2     2    30       13
# 147           김영사     9.2     3    37       12
# 148           김영사     9.2     4   137        7
# 149           김영사     9.2     5    33       13
# 150          은행나무     9.2     1    42       13
# 151          은행나무     9.2     2    47       11
# 152          은행나무     9.2     3    74        9
# 153          은행나무     9.2     4    76        9
# 154          은행나무     9.2     5     8       19
# 155            허블     9.4     1    65       11
# 156            허블     9.4     2    53       10
# 157            허블     9.4     3    46       11
# 158            허블     9.4     4    36       12
# 159            허블     9.4     5    33       13
# 160            해냄     9.3     1     4       22
# 161            해냄     9.3     2     4       19
# 162            해냄     9.3     3     9       18
# 163            해냄     9.3     4     6       20
# 164            해냄     9.3     5    18       16
# 165            해냄     9.2     1    30       14
# 166            해냄     9.2     2    21       15
# 167            해냄     9.2     3    28       13
# 168            해냄     9.2     4     9       18
# 169            해냄     9.2     5    18       16
# 170            해냄     9.2     1    30       14
# 171            해냄     9.2     2    13       16
# 172            해냄     9.2     3    28       13
# 173            해냄     9.2     4     9       18
# 174            해냄     9.2     5    22       15
# 175          문학동네     9.4     1     9       19
# 176          문학동네     9.4     2    34       12
# 177          문학동네     9.4     3    28       13
# 178          문학동네     9.4     4    21       14
# 179          문학동네     9.4     5    33       13
# 180          비에이블    10.0     1    14       17
# 181          비에이블    10.0     2   200        5
# 182          비에이블    10.0     3    20       14
# 183          비에이블    10.0     4    21       14
# 184          비에이블    10.0     5    87        9
# 185          문학사상     9.4     1   200        6
# 186          문학사상     9.4     2    30       13
# 187          문학사상     9.4     3     4       20
# 188          문학사상     9.4     4     2       24
# 189          문학사상     9.4     5     1       24
# 190          문학사상     9.4     1   200        6
# 191          문학사상     9.4     2    34       12
# 192          문학사상     9.4     3    16       16
# 193          문학사상     9.4     4     3       23
# 194          문학사상     9.4     5     1       24
# 195          은행나무     9.1     1    14       17
# 196          은행나무     9.1     2     4       19
# 197          은행나무     9.1     3    20       14
# 198          은행나무     9.1     4    36       12
# 199          은행나무     9.1     5   153        7

# %%
def montlyUseCntfill(data):
    if data['month']=='1':
        return 61500
    elif data['month']=='2':
        return 60000
    elif data['month']=='3':
        return 63000
    elif data['month']=='4':
        return 66000
    elif data['month']=='5':
        return 49500

# %%
def useAgeCntfill(data):
    if data['month']=='1':
        return 15067
    elif data['month']=='2':
        return 14700
    elif data['month']=='3':
        return 15435
    elif data['month']=='4':
        return 16170
    elif data['month']=='5':
        return 12127

# %%
ov40_loanData_JtoM['montlyUseCnt']=ov40_loanData_JtoM.apply(montlyUseCntfill, axis=1)

# %%
ov40_loanData_JtoM['useAgeCnt']=ov40_loanData_JtoM.apply(useAgeCntfill, axis=1)

# %%
def reverseRank(data):
    return 200-data['rank']

# %%
ov40_loanData_JtoM['rank']=ov40_loanData_JtoM.apply(reverseRank, axis=1)

# %%
ov40_loanData_JtoM
# Out:
#               ISBN                           bookName authorName  \
# 0    9788901246086                         2030 축의 전환     마우로 기옌
# 1    9788901246086                         2030 축의 전환     마우로 기옌
# 2    9788901246086                         2030 축의 전환     마우로 기옌
# 3    9788901246086                         2030 축의 전환     마우로 기옌
# 4    9788901246086                         2030 축의 전환     마우로 기옌
# 5    9791188331796                     [예스리커버] 돈의 속성         김승호
# 6    9791188331796                     [예스리커버] 돈의 속성         김승호
# 7    9791188331796                     [예스리커버] 돈의 속성         김승호
# 8    9791188331796                     [예스리커버] 돈의 속성         김승호
# 9    9791188331796                     [예스리커버] 돈의 속성         김승호
# 10   9791190090018         [예스리커버] 우리가 빛의 속도로 갈 수 없다면        김초엽
#
# 78           이타북스     8.8     4   183       15         66000      16170
# 79           이타북스     8.8     5   171       14         49500      12127
# 80            민음사     9.1     1   170       14         61500      15067
# 81            민음사     9.1     2   187       16         60000      14700
# 82            민음사     9.1     3   103        8         63000      15435
# 83            민음사     9.1     4    99        8         66000      16170
# 84            민음사     9.1     5   167       13         49500      12127
# 85           북플라자     8.5     1   135       11         61500      15067
# 86           북플라자     8.5     2   187       16         60000      14700
# 87           북플라자     8.5     3   172       13         63000      15435
# 88           북플라자     8.5     4   124        9         66000      16170
# 89           북플라자     8.5     5   149       11         49500      12127
# 90           페이지2     9.6     1   191       19         61500      15067
# 91           페이지2     9.6     2   187       16         60000      14700
# 92           페이지2     9.6     3   191       18         63000      15435
# 93           페이지2     9.6     4   141       10         66000      16170
# 94           페이지2     9.6     5    88        8         49500      12127
# 95   알에이치코리아(RHK)     8.7     1     0        6         61500      15067
# 96   알에이치코리아(RHK)     8.7     2    57        7         60000      14700
# 97   알에이치코리아(RHK)     8.7     3   196       20         63000      15435
# 98   알에이치코리아(RHK)     8.7     4   191       18         66000      16170
# 99   알에이치코리아(RHK)     8.7     5   167       13         49500      12127
# 100           김영사     9.2     1   194       21         61500      15067
# 101           김영사     9.2     2   179       15         60000      14700
# 102           김영사     9.2     3   103        8         63000      15435
# 103           김영사     9.2     4   124        9         66000      16170
# 104           김영사     9.2     5    47        7         49500      12127
# 105            창비     9.3     1   158       13         61500      15067
# 106            창비     9.3     2   176       14         60000      14700
# 107            창비     9.3     3   180       14         63000      15435
# 108            창비     9.3     4    63        7         66000      16170
# 109            창비     9.3     5   171       14         49500      12127
# 110            창비     9.2     1   170       14         61500      15067
# 111            창비     9.2     2   196       19         60000      14700
# 112            창비     9.2     3   186       17         63000      15435
# 113            창비     9.2     4   192       19         66000      16170
# 114            창비     9.2     5   188       17         49500      12127
# 115            창비     9.5     1    60        8         61500      15067
# 116            창비     9.5     2   197       21         60000      14700
# 117            창비     9.5     3   103        8         63000      15435
# 118            창비     9.5     4   155       11         66000      16170
# 119            창비     9.5     5   149       11         49500      12127
# 120          다산북스     9.4     1   147       12         61500      15067
# 121          다산북스     9.4     2   192       17         60000      14700
# 122          다산북스     9.4     3   191       18         63000      15435
# 123          다산북스     9.4     4   179       14         66000      16170
# 124          다산북스     9.4     5   113        9         49500      12127
# 125          밝은세상     9.2     1     0        6         61500      15067
# 126          밝은세상     9.2     2   147       10         60000      14700
# 127          밝은세상     9.2     3   184       16         63000      15435
# 128          밝은세상     9.2     4   196       22         66000      16170
# 129          밝은세상     9.2     5   194       20         49500      12127
# 130          베가북스     8.8     1   175       15         61500      15067
# 131          베가북스     8.8     2   192       17         60000      14700
# 132          베가북스     8.8     3   186       17         63000      15435
# 133          베가북스     8.8     4    63        7         66000      16170
# 134          베가북스     9.2     5     0        6         49500      12127
# 135         지식노마드     8.6     1   199       27         61500      15067
# 136         지식노마드     8.6     2   192       17         60000      14700
# 137         지식노마드     8.6     3   196       20         63000      15435
# 138         지식노마드     8.6     4   179       14         66000      16170
# 139         지식노마드     8.6     5   178       15         49500      12127
# 140        위즈덤하우스     9.6     1     0        6         61500      15067
# 141        위즈덤하우스     9.6     2    97        8         60000      14700
# 142        위즈덤하우스     9.6     3   182       15         63000      15435
# 143        위즈덤하우스     9.6     4   155       11         66000      16170
# 144        위즈덤하우스     9.6     5   189       18         49500      12127
# 145           김영사     9.2     1   180       16         61500      15067
# 146           김영사     9.2     2   170       13         60000      14700
# 147           김영사     9.2     3   163       12         63000      15435
# 148           김영사     9.2     4    63        7         66000      16170
# 149           김영사     9.2     5   167       13         49500      12127
# 150          은행나무     9.2     1   158       13         61500      15067
# 151          은행나무     9.2     2   153       11         60000      14700
# 152          은행나무     9.2     3   126        9         63000      15435
# 153          은행나무     9.2     4   124        9         66000      16170
# 154          은행나무     9.2     5   192       19         49500      12127
# 155            허블     9.4     1   135       11         61500      15067
# 156            허블     9.4     2   147       10         60000      14700
# 157            허블     9.4     3   154       11         63000      15435
# 158            허블     9.4     4   164       12         66000      16170
# 159            허블     9.4     5   167       13         49500      12127
# 160            해냄     9.3     1   196       22         61500      15067
# 161            해냄     9.3     2   196       19         60000      14700
# 162            해냄     9.3     3   191       18         63000      15435
# 163            해냄     9.3     4   194       20         66000      16170
# 164            해냄     9.3     5   182       16         49500      12127
# 165            해냄     9.2     1   170       14         61500      15067
# 166            해냄     9.2     2   179       15         60000      14700
# 167            해냄     9.2     3   172       13         63000      15435
# 168            해냄     9.2     4   191       18         66000      16170
# 169            해냄     9.2     5   182       16         49500      12127
# 170            해냄     9.2     1   170       14         61500      15067
# 171            해냄     9.2     2   187       16         60000      14700
# 172            해냄     9.2     3   172       13         63000      15435
# 173            해냄     9.2     4   191       18         66000      16170
# 174            해냄     9.2     5   178       15         49500      12127
# 175          문학동네     9.4     1   191       19         61500      15067
# 176          문학동네     9.4     2   166       12         60000      14700
# 177          문학동네     9.4     3   172       13         63000      15435
# 178          문학동네     9.4     4   179       14         66000      16170
# 179          문학동네     9.4     5   167       13         49500      12127
# 180          비에이블    10.0     1   186       17         61500      15067
# 181          비에이블    10.0     2     0        5         60000      14700
# 182          비에이블    10.0     3   180       14         63000      15435
# 183          비에이블    10.0     4   179       14         66000      16170
# 184          비에이블    10.0     5   113        9         49500      12127
# 185          문학사상     9.4     1     0        6         61500      15067
# 186          문학사상     9.4     2   170       13         60000      14700
# 187          문학사상     9.4     3   196       20         63000      15435
# 188          문학사상     9.4     4   198       24         66000      16170
# 189          문학사상     9.4     5   199       24         49500      12127
# 190          문학사상     9.4     1     0        6         61500      15067
# 191          문학사상     9.4     2   166       12         60000      14700
# 192          문학사상     9.4     3   184       16         63000      15435
# 193          문학사상     9.4     4   197       23         66000      16170
# 194          문학사상     9.4     5   199       24         49500      12127
# 195          은행나무     9.1     1   186       17         61500      15067
# 196          은행나무     9.1     2   196       19         60000      14700
# 197          은행나무     9.1     3   180       14         63000      15435
# 198          은행나무     9.1     4   164       12         66000      16170
# 199          은행나무     9.1     5    47        7         49500      12127

# %%
ISBNlist = []

# %%
def ISBNextract(data):
    for i in range(len(data)):
        if data['month'][i] == '5':
            ISBNlist.append(data['ISBN'][i])

# %%
train_dic = {'bookName':[], 'month':[], 
             'rank':[], 'montlyUseCnt':[],
             'useAgeCnt':[], 'loanCnt':[]}

# %%
train_df = pd.DataFrame(train_dic)

# %%
test_df = pd.DataFrame(train_dic)

# %%
ov40_loanData_JtoM.to_csv('gwangju_ov40_bestloan40.csv', encoding='cp949')

# %%
def traintestclf(data):
    for i in range(len(data)):
        trainlist=[]
        testlist=[]
        if data['month'][i] !='5':
            global train_df
            trainlist.append(data['bookName'][i])
            trainlist.append(data['month'][i])
            trainlist.append(data['rank'][i])
            trainlist.append(data['montlyUseCnt'][i])
            trainlist.append(data['useAgeCnt'][i])
            trainlist.append(data['loanCnt'][i])
            
            train_df = train_df.append(
                           pd.Series(trainlist, index=train_df.columns),
                           ignore_index=True
                           )
        else:
            global test_df
            testlist.append(data['bookName'][i])
            testlist.append(data['month'][i])
            testlist.append(data['rank'][i])
            testlist.append(data['montlyUseCnt'][i])
            testlist.append(data['useAgeCnt'][i])
            testlist.append(data['loanCnt'][i])
            
            test_df = test_df.append(
                          pd.Series(testlist, index=test_df.columns),
                          ignore_index=True
                          )

# %%
traintestclf(ov40_loanData_JtoM)

# %%
X_train = train_df.loc[:,:'useAgeCnt']
y_train = train_df['loanCnt']
X_test = test_df.loc[:,:'useAgeCnt']
y_test = test_df['loanCnt']

# %%
X_train['rank']=X_train['rank'].astype('int64')
X_train['montlyUseCnt']=X_train['montlyUseCnt'].astype('int64')
X_train['useAgeCnt']=X_train['useAgeCnt'].astype('int64')
X_test['rank']=X_test['rank'].astype('int64')
X_test['montlyUseCnt']=X_test['montlyUseCnt'].astype('int64')
X_test['useAgeCnt']=X_test['useAgeCnt'].astype('int64')

# %%
def monthtoseason(data):
    if data['month']== '1' or data['month']== '2':
        return 'winter'
    elif data['month']== '3' or data['month']== '4' or data['month']== '5':
        return 'spring'

# %%
X_train['season']=X_train.apply(monthtoseason, axis=1)

# %%
del X_train['month']

# %%
X_test['season']=X_test.apply(monthtoseason, axis=1)

# %%
del X_test['month']

# %%
y_train.to_csv('y_train_ov40.csv')

# %%
y_test.to_csv('y_test_ov40.csv')

# %%
X_train_one_hot = pd.get_dummies(X_train)
X_test_one_hot = pd.get_dummies(X_test)

# %%
X_test_one_hot['season_winter']=0

# %%
X_train_one_hot.to_csv('X_train_ov40.csv', encoding='cp949')

# %%
X_test_one_hot.to_csv('X_test_ov40.csv', encoding='cp949')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
scaler = StandardScaler()
scaler.fit(X_train_one_hot)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train_one_hot)
X_test = scaler.transform(X_test_one_hot)

# %%
from xgboost import XGBClassifier

# %%
kfold = KFold(n_splits=10, random_state=123, shuffle=True)

# %%
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.01, random_state=123)
xgb_model.fit(X_train, y_train)
# Out:
# C:\Users\21SMT018\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:23:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=16, num_parallel_tree=1,
#               objective='multi:softprob', random_state=123, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pre_xgb = xgb_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score

# %%
R2R2 = r2_score(
    pre_xgb,
    y_test,
)

# %%
R2R2
# Out:
# 0.935966437581077
